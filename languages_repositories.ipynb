# %% [markdown]
# Fisrt Request

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# [{'id': '35484432306',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 283287305,
#    'name': 'jonpulsifer/jonpulsifer',
#    'url': 'https://api.github.com/repos/jonpulsifer/jonpulsifer'},
#   'payload': {'repository_id': 283287305,
#    'push_id': 16988074336,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f452c4ddfa829d3e30458a886b94e405d371d5da',
#    'before': '105346ee6b0f7e83f9aa0e216e5864ca820c64f8',
#    'commits': [{'sha': 'f452c4ddfa829d3e30458a886b94e405d371d5da',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Update github-metrics.svg - [Skip GitHub Action]',
# ...

# %%
r = requests.get('https://api.github.com/versions') #selecting the api version
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %%
# specifying the API version
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'

# %%
response = requests.get(url, headers=headers)

# %%
response.json()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
len(response.json())
# Out:
# 30

# %%
access_token = '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'
headers = {'Authorization': 'Bearer ' + access_token,
           'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' # username de quem vamos extrair os dados
url = f'{api_base_url}/users/{owner}/repos'

# %%
repos_list = []
for page_num in range(1, 6):
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        repos_list.append(response.json())
    except:
        repos_list.append(None)

# %%
len(repos_list)
# Out:
# 5

# %%
repos_list[0]
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %% [markdown]
# Name of Repositories

# %%
repos_list[0][2]['name']
# Out:
# 'ads-pao-amznjs-gtm-template'

# %%
repos_name = []
for page in repos_list:
    for repo in page:
        repos_name.append(repo['name'])

# %%
repos_name[:10]
# Out:
# ['.github',
#  'ads-advanced-tools-docs',
#  'ads-pao-amznjs-gtm-template',
#  'alexa-coho',
#  'alexa-skills-kit-js',
#  'amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool',
#  'amazon-hub-counter-api-docs']

# %%
len(repos_name)
# Out:
# 148

# %% [markdown]
# Repository Languages

# %%
repos_list[1][1]['language']
# Out:
# 'PHP'

# %%
repos_language = []
for page in repos_list:
    for repo in page:
        repos_language.append(repo['language'])

# %%
len(repos_language)
# Out:
# 148

# %%
repos_language
# Out:
# [None,
#  None,
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS',
#  'Java',
#  'Java',
#  'PowerShell',
#  'Java',
#  'C#',
#  'PHP',
#  'Ruby',
#  'JavaScript',
#  'Python',
#  'PHP',
#  'Python',
#  'Jupyter Notebook',
#  'C#',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'C#',
#  'Java',
#  'PHP',
#  'Python',
#  'Ruby',
#  'PHP',
#  'Kotlin',
#  'PHP',
#  'Python',
#  'C',
#  'Kotlin',
#  'Swift',
#  'Python',
#  'C++',
#  'Python',
#  'Go',
#  'C',
#  'Python',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  None,
#  'Java',
#  'Kotlin',
#  'Python',
#  'JavaScript',
#  'TypeScript',
#  'Python',
#  'TypeScript',
#  'JavaScript',
#  'TypeScript',
#  'Python',
#  None,
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Java',
#  'Objective-C',
#  'JavaScript',
#  'TypeScript',
#  'Java',
#  None,
#  'Python',
#  'Python',
#  'Java',
#  'Java',
#  'Java',
# ...

# %% [markdown]
# Creating a DataFrame

# %%
import pandas as pd

# %%
amz_data = pd.DataFrame()
amz_data['repository_name'] = repos_name
amz_data['language'] = repos_language

# %%
amz_data
# Out:
#                  repository_name    language
# 0                        .github        None
# 1        ads-advanced-tools-docs        None
# 2    ads-pao-amznjs-gtm-template      Smarty
# 3                     alexa-coho  JavaScript
# 4            alexa-skills-kit-js        None
# ..                           ...         ...
# 143             zeek-plugin-enip        Zeek
# 144         zeek-plugin-profinet        Zeek
# 145           zeek-plugin-s7comm        Zeek
# 146              zeek-plugin-tds        Zeek
# 147               zero-shot-rlhr      Python
#
# [148 rows x 2 columns]

# %% [markdown]
# Saving DataFrame

# %%
amz_data.to_csv('amazon_repositories.csv')

# %% [markdown]
# Creating repository with POST

# %%
api_base_url = 'https://api.github.com'
url = f'{api_base_url}/user/repos'

url
# Out:
# 'https://api.github.com/user/repos'

# %%
data = {
    'name': 'languages_used',
    'description': 'Repository with amazon programming languages. This file was generated by Python script which gets information from amazon repositories using request library, GET method and saved in this repository, using POST method',
    'private': False
}

response = requests.post(url, json = data, headers=headers)
response.status_code
# Out:
# '{"id":754215646,"node_id":"R_kgDOLPRq3g","name":"languages_used","full_name":"alinept/languages_used","private":false,"owner":{"login":"alinept","id":5788476,"node_id":"MDQ6VXNlcjU3ODg0NzY=","avatar_url":"https://avatars.githubusercontent.com/u/5788476?v=4","gravatar_id":"","url":"https://api.github.com/users/alinept","html_url":"https://github.com/alinept","followers_url":"https://api.github.com/users/alinept/followers","following_url":"https://api.github.com/users/alinept/following{/other_user}","gists_url":"https://api.github.com/users/alinept/gists{/gist_id}","starred_url":"https://api.github.com/users/alinept/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/alinept/subscriptions","organizations_url":"https://api.github.com/users/alinept/orgs","repos_url":"https://api.github.com/users/alinept/repos","events_url":"https://api.github.com/users/alinept/events{/privacy}","received_events_url":"https://api.github.com/users/alinept/received_events","type":"Use
# ...

# %% [markdown]
# File format

# %%
import base64

with open('amazon_repositories.csv', 'rb') as file:
    file_content = file.read()

encoded_content = base64.b64encode(file_content)

# %% [markdown]
# File Upload with PUT method

# %%
api_base_url = 'https://api.github.com'
username = 'alinept'
repo = 'languages_used'
path = 'amazon_repositories.csv'

url = f'{api_base_url}/repos/{username}/{repo}/contents/{path}'
url
# Out:
# 'https://api.github.com/repos/alinept/languages_used/contents/amazon_repositories.csv'

# %%
data = {
    'message': 'Add a new file',
    'content': encoded_content.decode('utf8')
}

response = requests.put(url, json = data, headers=headers)
response.status_code
# Out:
# 201
